# %% [markdown]
# # 1. Import the Packages

# %%
# Standard Python libraries
import os
import random
import time
from datetime import datetime

# Libraries for data manipulation and visualization
import cv2
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# Libraries for detection and classification
from mtcnn import MTCNN 
from keras_facenet import FaceNet
# Out:
# WARNING:tensorflow:From C:\Users\lenovo\AppData\Roaming\Python\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # 2. Data Set Aquisition

# %% [markdown]
# Capturing data set for new user from camera using MTCNN detector

# %%
## BELOM BERES (LATER)

def captureImage():
    # initialize the MTCNN detector
    detector = MTCNN()

    # initialize the video capture object for the default camera
    cam = cv2.VideoCapture(0)

    # initialize catured frame variable

    while True:
        # read the frame from the camera
        ret, frame = cam.read()

        # detect faces using MTCNN
        faces = detector.detect_faces(frame)

        # draw bounding boxes around the faces
        for face in faces:
            x, y, w, h = face['box']
            cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 0, 255), 2)

        # show the resulting frame
        cv2.imshow('Real-time Face Detection', frame)

        # press 'q' key to exit
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    # release the video capture object and close all windows
    cam.release()
    cv2.destroyAllWindows()

# %% [markdown]
# ## 3. Preprocessing Image

# %% [markdown]
# ### 3.1. MTCNN Part

# %% [markdown]
# Extract faces from captured image using MTCNN and resize the image into 160x160. After that, do flip and contrast stretching to resized image

# %%
class FACELOADING:
    def __init__(self, directory):
        self.directory = directory
        self.target_size = (160, 160)
        self.X = []
        self.Y = []
        self.detector = MTCNN()

    def extract_faces(self, filename):
        img = cv2.imread(filename)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        hasil_deteksi = self.detector.detect_faces(img)

        # Getting x, y, w, h from image 'box'
        x, y, w, h = hasil_deteksi[0]['box']
        x, y, w, h = abs(x), abs(y), abs(w), abs(h)

        # Draw rectangle box on detected face
        img = cv2.rectangle(img, (x, y), (x+w, y+h), (0, 0, 255), 10)

        wajah = img[y:y + h, x:x + w]
        wajah_arr = cv2.resize(wajah, self.target_size)
        return wajah_arr

    def load_faces(self, dir, class_label):
        FACES = []
        Y = []
        for im_name in os.listdir(dir):
            try:
                path = os.path.join(dir, im_name)
                single_face = self.extract_faces(path)
                FACES.append(single_face)
                Y.append(class_label)

            except Exception as e:
                pass
        return FACES, Y

    def parse_filename(self, filename):
        # Mengambil NIM dan Nama dari nama file dengan pola "NIM_Nama_i.jpg"
        nim, nama, _ = filename.split('_')
        return nim, nama

    def load_classes_after_augmentation(self, output_folder=None):
        # Inisialisasi kembali X dan Y
        X = []
        Y = []

        # Membuat subdirektori yang belum ada
        if output_folder:
            for class_label in set(self.Y):  # Menggunakan set(Y) untuk mendapatkan kelas unik
                class_dir = os.path.join(output_folder, class_label)
                if not os.path.exists(class_dir):
                    os.makedirs(class_dir)

        for sub_dir in os.listdir(self.directory):
            path = os.path.join(self.directory, sub_dir)
            FACES, labels = self.load_faces_after_augmentation(path, sub_dir, output_folder=output_folder)
            X.extend(FACES)
            Y.extend(labels)

        return X, Y

    def load_faces_after_augmentation(self, dir, class_label, output_folder=None):
        FACES = []
        Y = []
        for i, im_name in enumerate(os.listdir(dir)):
            try:
                path = os.path.join(dir, im_name)
                single_face = self.extract_faces(path)
                FACES.append(single_face)
                Y.append(class_label)

                nim, nama = self.parse_filename(im_name)

                # Check if the output folder exists for the current class label
                class_output_folder = os.path.join(output_folder, class_label)
                if not os.path.exists(class_output_folder):
                    os.makedirs(class_output_folder)    

                # Jika ingin melakukan augmentasi pada citra di sini, tambahkan proses augmentasi di sini.
                flipped_face = cv2.flip(single_face, 1)  # 1 for horizontal flip
                FACES.append(flipped_face)
                Y.append(class_label)

                contrast_stretched_face = self.contrast_stretching(single_face)
                FACES.append(contrast_stretched_face)
                Y.append(class_label)

                if output_folder:
                    index_start = 1 + i * 3

                    # Simpan citra dengan penamaan yang mengikuti nim dan nama
                    original_filename = f"{nim}_{nama}_{index_start}.jpg"
                    output_path_original = os.path.join(output_folder, class_label, original_filename)
                    cv2.imwrite(output_path_original, cv2.cvtColor(single_face, cv2.COLOR_RGB2BGR))

                    flipped_filename = f"{nim}_{nama}_{index_start + 1}.jpg"
                    output_path_flip = os.path.join(output_folder, class_label, flipped_filename)
                    cv2.imwrite(output_path_flip, cv2.cvtColor(flipped_face, cv2.COLOR_RGB2BGR))

                    stretched_filename = f"{nim}_{nama}_{index_start + 2}.jpg"
                    output_path_stretch = os.path.join(output_folder, class_label, stretched_filename)
                    cv2.imwrite(output_path_stretch, cv2.cvtColor(contrast_stretched_face, cv2.COLOR_RGB2BGR))

            except Exception as e:
                pass
        return FACES, Y

    def contrast_stretching(self, image):
        # Compute minimum and maximum pixel values for each channel
        min_val = np.min(image, axis=(0, 1))
        max_val = np.max(image, axis=(0, 1))

        # Perform contrast stretching for each channel
        stretched = (image - min_val) * (255.0 / (max_val - min_val))
        stretched = np.clip(stretched, 0, 255).astype(np.uint8)

        return stretched

# %%
# Ask the user if they want to use the existing dataset or capture new images
use_existing_data = input("Do you want to use the last existing dataset (y/n)? ")
faces_dataset_filename = "dataframe_and_model_files/loadedfaces.npz"

# If the user wants to use the existing dataset, load the dataset from the .npz file
if use_existing_data.lower() == 'y':
    # Loads the faces and labels from the compressed .npz file.
    loaded_data = np.load("dataframe_and_model_files/loadedfaces.npz")
    X = loaded_data["X"]
    Y = loaded_data["Y"]

    print(f"Faces Dataset successfully loaded from {faces_dataset_filename}")
    print(f"===============================================")

    print(f"Unique Labels After Augmentation: {set(Y)}")
    print(f'Total Images in Array After Augmentation: {len(X)} images')

if use_existing_data.lower() == 'n':
    # Gunakan kelas FACELOADING dengan folder direktori "capturedfaces"
    face_loader = FACELOADING("capturedfaces")
    X, Y = face_loader.load_classes_after_augmentation(output_folder="datawajah")

    print(f"Unique Labels After Augmentation: {set(Y)}")
    print(f'Total Images in Array After Augmentation: {len(X)} images')

    # Saves the loaded faces and labels into a compressed .npz file
    joblib.dump()
    np.savez_compressed(faces_dataset_filename, X=X, Y=Y)
    print()
    print("File loaded and saved to dataframe_and_model_files/loadedfaces.npz")
# Out:
# Faces Dataset successfully loaded from dataframe_and_model_files/loadedfaces.npz
# ===============================================
# Unique Labels After Augmentation: {'shabrina-katresnawati', 'muhammad-tegar-heidar-gunawan', 'rizky-mahesa-ramadhan', 'ismail-nurhapid-jamal', 'zidan-nuryawan-pratomo', 'rahayu-puspitasari', 'rizky-nurhadhi'}
# Total Images in Array After Augmentation: 2100 images

# %% [markdown]
# Creating dataframe that containing available images from extracted faces and checking total files in the folder

# %%
def create_dataframe():
    # Initialize main dataset folder
    dataset_folder = "datawajah"
    root_folder = dataset_folder

    data = []
  
    # Iterate through the main folder and subfolders
    for root, dirs, files in os.walk(root_folder):
        for file in files:
        # Get the subfolder name (classes)
            classes = os.path.basename(root)

            # Get the full path of the image
            image_path = os.path.join(classes, file)

            # Add data to the list
            data.append({'Classes': classes, 'File Name': file, 'Image Path': image_path})

    # Create a dataframe from the data list
    df = pd.DataFrame(data)

    # Save the dataframe to an Excel file
    excel_file_name = 'dataframe_and_model_files/faces_train_data.xlsx'
    df.to_excel(excel_file_name, index=False)

    print("Dataframe successfully saved to", excel_file_name)

    return df

# %%
def total_images_per_class(df):
    # Function to calculate the total number of files in a folder.
    def total_file(classes):
        return len(df[df['Classes'] == classes].values)

    # Iterate through unique classes and print the total number of files for each class
    unique_classes = df['Classes'].unique()
    print("Total number of images in each class :")
    for classes in unique_classes:
        count = total_file(classes)
        print(f"'{classes}': {count} images")

# %%
# Create the dataframe
df = create_dataframe()

# Calculate and print the total number of images in each class
total_images_per_class(df)
# Out:
# Dataframe successfully saved to dataframe_and_model_files/faces_train_data.xlsx
# Total number of images in each class :
# 'ismail-nurhapid-jamal': 300 images
# 'muhammad-tegar-heidar-gunawan': 300 images
# 'rahayu-puspitasari': 300 images
# 'rizky-mahesa-ramadhan': 300 images
# 'rizky-nurhadhi': 300 images
# 'shabrina-katresnawati': 300 images
# 'zidan-nuryawan-pratomo': 300 images

# %%
df.sample(10)
# Out:
#                             Classes  \
# 1256                 rizky-nurhadhi
# 1662          shabrina-katresnawati
# 1630          shabrina-katresnawati
# 411   muhammad-tegar-heidar-gunawan
# 1940         zidan-nuryawan-pratomo
# 1299                 rizky-nurhadhi
# 1082          rizky-mahesa-ramadhan
# 702              rahayu-puspitasari
# 1786          shabrina-katresnawati
# 1836         zidan-nuryawan-pratomo
#
#                                            File Name  \
# 1256                1207070113_RIZKY NURHADHI_15.jpg
# 1662        1207070136_SHABRINA KATRESNAWATI_245.jpg
# 1630        1207070136_SHABRINA KATRESNAWATI_216.jpg
# 411   1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_2.jpg
# 1940             1207070132_ZIDAN NURYAWAN P_225.jpg
# 1299               1207070113_RIZKY NURHADHI_189.jpg
# 1082        1207070112_RIZKY MAHESA RAMADHAN_263.jpg
# 702            1207070094_RAHAYU PUSPITASARI_191.jpg
# 1786         1207070136_SHABRINA KATRESNAWATI_87.jpg
# 1836             1207070132_ZIDAN NURYAWAN P_131.jpg
#
#                                              Image Path
# 1256    rizky-nurhadhi\1207070113_RIZKY NURHADHI_15.jpg
# 1662  shabrina-katresnawati\1207070136_SHABRINA KATR...
# 1630  shabrina-katresnawati\1207070136_SHABRINA KATR...
# 411   muhammad-tegar-heidar-gunawan\1207070080_MUHAM...
# 1940  zidan-nuryawan-pratomo\1207070132_ZIDAN NURYAW...
# 1299   rizky-nurhadhi\1207070113_RIZKY NURHADHI_189.jpg
# 1082  rizky-mahesa-ramadhan\1207070112_RIZKY MAHESA ...
# 702   rahayu-puspitasari\1207070094_RAHAYU PUSPITASA...
# 1786  shabrina-katresnawati\1207070136_SHABRINA KATR...
# 1836  zidan-nuryawan-pratomo\1207070132_ZIDAN NURYAW...

# %% [markdown]
# ### 3.2. FaceNet Part

# %% [markdown]
# Embed the dataset to 512 dimension image (1x1x512) and save it into .npz file

# %%
embedder = FaceNet()

def get_embedding(face_image):
    face_image = face_image.astype('float32') # 3D(160x160x3)
    face_image = np.expand_dims(face_image, axis=0) # 4D(Nonex160x160x3)
    
    yhat = embedder.embeddings(face_image)

    return yhat[0] #512D image (1x1x152)
# Out:
# WARNING:tensorflow:From C:\Users\lenovo\AppData\Roaming\Python\Python311\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\lenovo\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.

# %%
embedded_data_loaded = input("Do you want to load last saved embedded data from the file 'dataframe_and_model_files/embedded_dataset.npz' (y/n)? ")
embedded_file_name = "dataframe_and_model_files/embedded_dataset.npz"

if embedded_data_loaded.lower() == 'y':
    # Load the embedded data from the npz file
    loaded_data = np.load('dataframe_and_model_files/embedded_dataset.npz', allow_pickle=True)
    EMBEDDED_X = loaded_data['arr_0']
    Y = loaded_data['arr_1']

    # Reload the arrays of original X
    loaded_data = np.load("dataframe_and_model_files/loadedfaces.npz")
    X = loaded_data["X"]

    print(f"Embedded dataset successfully loaded from {embedded_file_name}")
    print()
    print(f"Unique Labels: {set(Y)}")
    print(f'Total Embedded Images in Array: {len(EMBEDDED_X)}')
    
if embedded_data_loaded.lower() == 'n':
    # Embedding the datasets and save it to the npz file
    EMBEDDED_X = []

    for face_image in X:
        EMBEDDED_X.append(get_embedding(face_image))

    EMBEDDED_X = np.asarray(EMBEDDED_X)
    np.savez_compressed(embedded_file_name, EMBEDDED_X, Y)
    print("Embedded dataset successfully saved to", embedded_file_name)
    print("===============================================")
    print(f"Unique Labels: {set(Y)}")
    print(f'Total Embedded Images in Array: {len(EMBEDDED_X)}')
# Out:
# Embedded dataset successfully loaded from dataframe_and_model_files/embedded_dataset.npz
#
# Unique Labels: {'shabrina-katresnawati', 'muhammad-tegar-heidar-gunawan', 'rizky-mahesa-ramadhan', 'ismail-nurhapid-jamal', 'zidan-nuryawan-pratomo', 'rahayu-puspitasari', 'rizky-nurhadhi'}
# Total Embedded Images in Array: 2100

# %%
# Choose a few random indices
num_display_samples = 5
sample_indices = random.sample(range(len(EMBEDDED_X)), num_display_samples)

# Display the sample images with their corresponding labels and embeddings
plt.figure(figsize=(15, 6))
for i, index in enumerate(sample_indices):
    plt.subplot(2, num_display_samples, i + 1)
    plt.imshow(X[index])
    plt.title(f"Original: {Y[index]}")
    plt.axis('off')

    plt.subplot(2, num_display_samples, i + num_display_samples + 1)
    plt.imshow(EMBEDDED_X[index].reshape((1, -1)))
    plt.title(f"Embedded: {Y[index]}")
    plt.axis('off')

plt.tight_layout()

# %%
# Check correspondence between images in 'X' and labels in 'Y'
for i in range(len(X)):
    print(f"Label: {Y[i]}, File Name: {df['File Name'].iloc[i]}")
# Out:
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_1.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_10.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_100.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_101.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_102.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_103.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_104.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_105.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_106.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_107.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_108.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_109.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_11.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_110.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_111.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_112.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_113.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_114.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_115.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_116.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_117.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_118.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_119.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_12.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_120.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_121.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_122.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_123.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_124.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_125.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_126.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_127.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_128.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_129.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_13.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_130.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_131.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_132.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_133.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_134.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_135.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_136.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_137.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_138.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_139.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_14.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_140.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_141.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_142.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_143.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_144.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_145.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_146.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_147.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_148.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_149.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_15.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_150.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_151.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_152.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_153.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_154.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_155.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_156.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_157.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_158.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_159.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_16.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_160.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_161.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_162.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_163.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_164.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_165.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_166.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_167.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_168.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_169.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_17.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_170.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_171.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_172.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_173.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_174.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_175.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_176.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_177.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_178.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_179.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_18.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_180.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_181.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_182.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_183.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_184.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_185.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_186.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_187.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_188.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_189.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_19.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_190.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_191.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_192.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_193.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_194.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_195.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_196.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_197.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_198.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_199.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_2.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_20.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_200.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_201.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_202.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_203.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_204.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_205.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_206.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_207.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_208.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_209.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_21.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_210.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_211.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_212.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_213.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_214.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_215.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_216.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_217.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_218.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_219.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_22.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_220.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_221.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_222.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_223.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_224.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_225.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_226.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_227.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_228.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_229.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_23.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_230.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_231.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_232.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_233.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_234.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_235.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_236.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_237.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_238.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_239.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_24.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_240.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_241.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_242.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_243.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_244.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_245.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_246.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_247.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_248.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_249.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_25.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_250.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_251.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_252.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_253.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_254.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_255.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_256.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_257.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_258.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_259.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_26.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_260.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_261.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_262.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_263.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_264.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_265.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_266.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_267.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_268.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_269.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_27.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_270.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_271.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_272.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_273.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_274.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_275.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_276.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_277.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_278.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_279.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_28.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_280.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_281.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_282.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_283.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_284.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_285.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_286.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_287.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_288.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_289.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_29.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_290.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_291.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_292.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_293.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_294.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_295.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_296.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_297.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_298.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_299.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_3.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_30.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_300.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_31.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_32.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_33.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_34.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_35.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_36.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_37.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_38.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_39.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_4.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_40.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_41.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_42.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_43.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_44.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_45.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_46.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_47.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_48.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_49.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_5.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_50.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_51.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_52.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_53.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_54.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_55.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_56.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_57.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_58.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_59.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_6.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_60.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_61.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_62.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_63.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_64.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_65.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_66.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_67.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_68.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_69.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_7.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_70.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_71.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_72.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_73.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_74.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_75.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_76.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_77.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_78.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_79.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_8.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_80.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_81.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_82.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_83.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_84.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_85.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_86.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_87.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_88.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_89.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_9.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_90.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_91.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_92.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_93.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_94.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_95.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_96.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_97.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_98.jpg
# Label: ismail-nurhapid-jamal, File Name: 1207070060_ISMAIL NURHAPID JAMAL_99.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_1.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_10.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_100.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_101.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_102.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_103.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_104.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_105.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_106.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_107.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_108.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_109.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_11.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_110.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_111.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_112.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_113.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_114.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_115.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_116.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_117.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_118.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_119.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_12.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_120.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_121.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_122.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_123.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_124.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_125.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_126.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_127.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_128.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_129.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_13.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_130.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_131.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_132.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_133.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_134.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_135.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_136.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_137.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_138.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_139.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_14.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_140.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_141.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_142.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_143.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_144.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_145.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_146.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_147.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_148.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_149.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_15.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_150.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_151.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_152.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_153.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_154.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_155.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_156.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_157.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_158.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_159.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_16.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_160.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_161.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_162.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_163.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_164.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_165.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_166.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_167.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_168.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_169.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_17.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_170.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_171.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_172.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_173.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_174.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_175.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_176.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_177.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_178.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_179.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_18.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_180.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_181.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_182.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_183.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_184.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_185.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_186.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_187.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_188.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_189.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_19.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_190.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_191.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_192.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_193.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_194.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_195.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_196.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_197.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_198.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_199.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_2.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_20.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_200.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_201.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_202.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_203.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_204.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_205.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_206.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_207.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_208.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_209.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_21.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_210.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_211.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_212.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_213.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_214.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_215.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_216.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_217.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_218.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_219.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_22.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_220.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_221.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_222.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_223.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_224.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_225.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_226.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_227.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_228.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_229.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_23.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_230.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_231.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_232.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_233.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_234.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_235.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_236.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_237.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_238.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_239.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_24.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_240.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_241.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_242.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_243.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_244.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_245.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_246.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_247.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_248.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_249.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_25.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_250.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_251.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_252.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_253.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_254.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_255.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_256.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_257.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_258.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_259.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_26.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_260.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_261.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_262.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_263.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_264.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_265.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_266.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_267.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_268.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_269.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_27.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_270.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_271.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_272.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_273.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_274.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_275.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_276.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_277.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_278.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_279.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_28.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_280.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_281.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_282.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_283.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_284.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_285.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_286.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_287.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_288.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_289.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_29.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_290.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_291.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_292.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_293.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_294.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_295.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_296.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_297.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_298.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_299.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_3.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_30.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_300.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_31.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_32.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_33.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_34.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_35.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_36.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_37.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_38.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_39.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_4.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_40.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_41.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_42.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_43.jpg
# Label: muhammad-tegar-heidar-gunawan, File Name: 1207070080_MUHAMMAD TEGAR HEIDAR GUNAWAN_44.jpg
# ...
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_184.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_185.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_186.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_187.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_188.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_189.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_19.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_190.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_191.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_192.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_193.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_194.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_195.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_196.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_197.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_198.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_199.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_2.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_20.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_200.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_201.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_202.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_203.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_204.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_205.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_206.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_207.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_208.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_209.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_21.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_210.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_211.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_212.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_213.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_214.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_215.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_216.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_217.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_218.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_219.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_22.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_220.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_221.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_222.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_223.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_224.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_225.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_226.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_227.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_228.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_229.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_23.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_230.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_231.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_232.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_233.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_234.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_235.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_236.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_237.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_238.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_239.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_24.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_240.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_241.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_242.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_243.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_244.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_245.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_246.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_247.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_248.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_249.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_25.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_250.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_251.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_252.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_253.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_254.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_255.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_256.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_257.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_258.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_259.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_26.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_260.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_261.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_262.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_263.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_264.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_265.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_266.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_267.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_268.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_269.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_27.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_270.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_271.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_272.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_273.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_274.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_275.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_276.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_277.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_278.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_279.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_28.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_280.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_281.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_282.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_283.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_284.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_285.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_286.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_287.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_288.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_289.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_29.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_290.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_291.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_292.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_293.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_294.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_295.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_296.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_297.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_298.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_299.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_3.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_30.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_300.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_31.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_32.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_33.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_34.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_35.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_36.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_37.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_38.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_39.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_4.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_40.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_41.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_42.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_43.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_44.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_45.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_46.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_47.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_48.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_49.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_5.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_50.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_51.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_52.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_53.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_54.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_55.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_56.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_57.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_58.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_59.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_6.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_60.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_61.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_62.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_63.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_64.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_65.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_66.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_67.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_68.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_69.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_7.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_70.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_71.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_72.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_73.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_74.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_75.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_76.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_77.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_78.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_79.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_8.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_80.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_81.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_82.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_83.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_84.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_85.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_86.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_87.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_88.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_89.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_9.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_90.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_91.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_92.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_93.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_94.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_95.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_96.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_97.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_98.jpg
# Label: zidan-nuryawan-pratomo, File Name: 1207070132_ZIDAN NURYAWAN P_99.jpg

# %% [markdown]
# ## 4. SVM Classification

# %% [markdown]
# ### 4.1. K-Fold Cross Validation

# %%
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn import svm
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data from the npz file
loaded_data = np.load('dataframe_and_model_files/embedded_dataset.npz', allow_pickle=True)
X = loaded_data['arr_0']
Y = loaded_data['arr_1']

# Perform Stratified K-fold cross validation
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Initialize arrays to store the train and test embeddings and labels
X_train_folds = []
X_test_folds = []
y_train_folds = []
y_test_folds = []

# Perform Stratified K-fold cross validation
for train_index, test_index in skf.split(X, Y):
    X_train_folds.append(X[train_index])
    X_test_folds.append(X[test_index])
    y_train_folds.append(np.take(Y, train_index))
    y_test_folds.append(Y[test_index])

# Initialize the SVM classifier
svm_classifier = svm.SVC(kernel='linear', probability=True)

# Initialize empty lists to store the train and test predictions
train_predictions = []
test_predictions = []

# Store the trained model and test predictions for each fold
fold_models = []
fold_test_predictions = []
model_filename = "dataframe_and_model_files/mtcnn_svm_model_facercognition.npz"

for i in range(skf.get_n_splits()):
    svm_classifier.fit(X_train_folds[i], y_train_folds[i])
    train_predictions.append(svm_classifier.predict(X_train_folds[i]))
    test_predictions.append(svm_classifier.predict(X_test_folds[i]))

    # Save the trained model, test predictions, and true labels for this fold
    fold_models.append(svm_classifier)
    fold_test_predictions.append(np.vstack((test_predictions[i], y_test_folds[i])).T)

# Save the models, test predictions, and true labels to a file
np.savez(model_filename, models=fold_models, test_predictions=fold_test_predictions)

# Calculate the accuracy, precision, recall, and F1 score for each fold
accuracies = []
precisions = []
recalls = []
f1_scores = []
for i in range(skf.get_n_splits()):
    accuracies.append(accuracy_score(y_train_folds[i], train_predictions[i]))
    precisions.append(precision_score(y_train_folds[i], train_predictions[i], average='weighted'))
    recalls.append(recall_score(y_train_folds[i], train_predictions[i], average='weighted'))
    f1_scores.append(f1_score(y_train_folds[i], train_predictions[i], average='weighted'))
    print(f'Fold {i+1} - Train Accuracy: {accuracies[i]*100:.2f}%, '
          f'Precision: {precisions[i]*100:.2f}%%, '
          f'Recall: {recalls[i]*100:.2f}%%, '
          f'F1 Score: {f1_scores[i]*100:.2f}%')
    print(f'Fold {i+1} - Test Accuracy: {accuracy_score(y_test_folds[i], test_predictions[i])*100:.2f}%')
    print()

# Calculate the average accuracy, precision, recall, and F1 score
avg_accuracy = np.mean(accuracies)
avg_precision = np.mean(precisions)
avg_recall = np.mean(recalls)
avg_f1_score = np.mean(f1_scores)

print(f'Average Accuracy: {avg_accuracy*100}%')
print(f'Average Precision: {avg_precision*100}%')
print(f'Average Recall: {avg_recall*100}%')
print(f'Average F1 Score: {avg_f1_score*100}%')

# Calculate the confusion matrix for each fold
confusion_matrices = []
for i in range(skf.get_n_splits()):
    y_true = y_test_folds[i]
    y_pred = test_predictions[i]
    confusion_mtx = confusion_matrix(y_true, y_pred)
    confusion_matrices.append(confusion_mtx)

# Sum up the confusion matrices
confusion_mtx = np.sum(confusion_matrices, axis=0)

# Get the unique classes from the true labels
classes = np.unique(y_true)

# Create a confusion matrix with labels instead of integer values
confusion_mtx_labels = confusion_matrix(y_true, y_pred, labels=classes)

# Plot the confusion matrix with labels instead of integer values
sns.heatmap(confusion_mtx_labels, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted label')
plt.ylabel('True label')

# Set the xticklabels and yticklabels to the unique classes
plt.xticks(ticks=range(len(classes)), labels=classes)
plt.yticks(ticks=range(len(classes)), labels=classes)
plt.tight_layout()
plt.show()
# Out:
# Fold 1 - Train Accuracy: 100.00%, Precision: 100.00%%, Recall: 100.00%%, F1 Score: 100.00%
# Fold 1 - Test Accuracy: 100.00%
#
# Fold 2 - Train Accuracy: 100.00%, Precision: 100.00%%, Recall: 100.00%%, F1 Score: 100.00%
# Fold 2 - Test Accuracy: 100.00%
#
# Fold 3 - Train Accuracy: 100.00%, Precision: 100.00%%, Recall: 100.00%%, F1 Score: 100.00%
# Fold 3 - Test Accuracy: 100.00%
#
# Fold 4 - Train Accuracy: 100.00%, Precision: 100.00%%, Recall: 100.00%%, F1 Score: 100.00%
# Fold 4 - Test Accuracy: 100.00%
#
# Fold 5 - Train Accuracy: 100.00%, Precision: 100.00%%, Recall: 100.00%%, F1 Score: 100.00%
# Fold 5 - Test Accuracy: 100.00%
#
# Average Accuracy: 100.0%
# Average Precision: 100.0%
# Average Recall: 100.0%
# Average F1 Score: 100.0%

# %%
import cv2
import numpy as np
import time
from mtcnn import MTCNN
import joblib

# Load MTCNN face detection model
detector = MTCNN()

# Load saved model
model_filename = "dataframe_and_model_files/mtcnn_svm_model_facercognition.npz"
model = np.load(model_filename)

# Initialize the camera
cap = cv2.VideoCapture(0)

# Initialize a variable to keep track of the start time
start_time = time.time()

while True:
    # Capture frame from the camera
    ret, frame = cap.read()

    # Calculate the elapsed time
    elapsed_time = time.time() - start_time

    # If 10 seconds have elapsed, break the loop
    if elapsed_time > 10:
        break

# Release the camera
cap.release()
cv2.destroyAllWindows()

# Capture the frame at the 10th second
while elapsed_time < 10:
    # Capture frame from the camera
    ret, frame = cap.read()

    # Calculate the elapsed time
    elapsed_time = time.time() - start_time

# Detect faces in the frame
faces = detector.detect_faces(frame)

# Initialize empty list to store the detected faces
detected_faces = []

# Extract detected faces
for face in faces:
    x, y, w, h = face['box']
    detected_faces.append(frame[y:y+h, x:x+w])

# Recognize faces
recognized_faces = []
for face in detected_faces:
    face = cv2.resize(face, (160, 160))
    face = np.expand_dims(face, axis=0)
    face = face.astype('float32')
    pred = model.predict(face)
    recognized_faces.append(pred[0])

# Print recognized faces
print(recognized_faces)

# Release the camera
cap.release()
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 231ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 112ms/step
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 60
#      58     face = np.expand_dims(face, axis=0)
#      59     face = face.astype('float32')
# ---> 60     pred = model.predict(face)
#      61     recognized_faces.append(pred[0])
#      63 # Print recognized faces
#
# AttributeError: 'NpzFile' object has no attribute 'predict'

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from mtcnn import MTCNN
from keras_facenet import FaceNet

# Load the saved model
model_filename = "dataframe_and_model_files/mtcnn_svm_model_facercognition.npz"
loaded_data = np.load(model_filename, allow_pickle=True)
fold_models = loaded_data['models']

# Load the FaceNet model
embedder = FaceNet()

# Initialize the MTCNN face detection algorithm
detector = MTCNN()

# Open the camera
cap = cv2.VideoCapture(0)

while True:
    # Capture a frame from the camera
    ret, frame = cap.read()

    # Detect faces in the frame
    faces = detector.detect_faces(frame)

    # Extract the detected faces as 160x160 RGB images
    extracted_faces = []
    for face in faces:
        x, y, w, h = face['box']
        face_image = frame[y:y+h, x:x+w]
        face_image = cv2.resize(face_image, (160, 160))
        face_image = cv2.cvtColor(face_image, cv2.COLOR_BGR2RGB)
        extracted_faces.append(face_image)

    # Embed the extracted faces using the FaceNet model
    embeddings = []
    for face in extracted_faces:
        embedding = embedder.embeddings(np.array([face]))
        embeddings.append(embedding[0])

    # Use the saved SVM model to predict the label of each embedding
    labels = []
    for embedding in embeddings:
        # Reshape the embedding to (1, 128) for the SVM model
        embedding = np.array([embedding.reshape(1, -1)])
        # Use the first model to predict the label
        label = fold_models[0].predict(embedding)[0]
        labels.append(label)

    # Display the predicted labels on the detected faces in the frame
    for i, face in enumerate(faces):
        x, y, w, h = face['box']
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
        cv2.putText(frame, str(labels[i]), (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)

    # Display the frame
    cv2.imshow('Face Recognition', frame)

    # Exit the loop if the 'q' key is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the camera and destroy all windows
cap.release()
cv2.destroyAllWindows()

# %%
# import cv2
# import numpy as np
# import time
# from mtcnn import MTCNN
# from sklearn.externals import joblib

# # Load MTCNN face detection model
# detector = MTCNN()

# # Load saved model
# model = joblib.load('mtcnn_svm_model_facerecognition.npz')

# # Initialize the camera
# cap = cv2.VideoCapture(0)

# # Initialize a variable to keep track of the start time
# start_time = time.time()

# while True:
#     # Capture frame from the camera
#     ret, frame = cap.read()

#     # Calculate the elapsed time
#     elapsed_time = time.time() - start_time

#     # If 10 seconds have elapsed, break the loop
#     if elapsed_time > 10:
#         break

# # Release the camera
# cap.release()
# cv2.destroyAllWindows()

# # Capture the frame at the 10th second
# while elapsed_time < 10:
#     # Capture frame from the camera
#     ret, frame = cap.read()

#     # Calculate the elapsed time
#     elapsed_time = time.time() - start_time

# # Detect faces in the frame
# faces = detector.detect_faces(frame)

# # Initialize empty list to store the detected faces
# detected_faces = []

# # Extract detected faces
# for face in faces:
#     x, y, w, h = face['box']
#     detected_faces.append(frame[y:y+h, x:x+w])

# # Recognize faces
# recognized_faces = []
# for face in detected_faces:
#     face = cv2.resize(face, (160, 160))
#     face = np.expand_dims(face, axis=0)
#     face = face.astype('float32')
#     pred = model.predict(face)
#     recognized_faces.append(pred[0])

# # Print recognized faces
# print(recognized_faces)

# # Release the camera
# cap.release()
# cv2.destroyAllWindows()

# %% [markdown]
# ### 4.2. Re-Training Model
